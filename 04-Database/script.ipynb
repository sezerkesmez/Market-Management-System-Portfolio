-- %% [markdown]
-- # [dbo].[AlisDetay]

-- %%
USE [kafa20]
GO

-- %%
/****** Object:  Table [dbo].[AlisDetay]    Script Date: 29.01.2026 12:42:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AlisDetay](
	[DetayId] [int] IDENTITY(1,1) NOT NULL,
	[AlisId] [int] NULL,
	[StokId] [int] NULL,
	[Adet] [int] NULL,
	[Fiyat] [decimal](18, 2) NULL,
	[Tutar]  AS ([Adet]*[Fiyat]) PERSISTED,
PRIMARY KEY CLUSTERED 
(
	[DetayId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Alislar]

-- %%
/****** Object:  Table [dbo].[Alislar]    Script Date: 29.01.2026 12:42:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Alislar](
	[AlisId] [int] IDENTITY(1,1) NOT NULL,
	[TedarikciId] [int] NULL,
	[Tarih] [datetime] NULL,
	[ToplamTutar] [decimal](18, 2) NULL,
	[FaturaNo] [nvarchar](50) NULL,
	[AlisOdemeTipi] [nvarchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[AlisId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[KasaHareket]

-- %%
/****** Object:  Table [dbo].[KasaHareket]    Script Date: 29.01.2026 12:42:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[KasaHareket](
	[HareketId] [int] IDENTITY(1,1) NOT NULL,
	[Tarih] [datetime] NOT NULL,
	[Tutar] [decimal](18, 2) NOT NULL,
	[OdemeTipi] [nvarchar](10) NOT NULL,
	[Aciklama] [nvarchar](200) NULL,
	[IslemTuru] [nvarchar](20) NULL,
	[IlgiliFaturaNo] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[HareketId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MarketSettings]

-- %%
/****** Object:  Table [dbo].[MarketSettings]    Script Date: 29.01.2026 12:42:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MarketSettings](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OpeningTime] [time](7) NOT NULL,
	[ClosingTime] [time](7) NOT NULL,
	[IsNextDay] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SatisDetay]

-- %%
/****** Object:  Table [dbo].[SatisDetay]    Script Date: 29.01.2026 12:42:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SatisDetay](
	[DetayId] [int] IDENTITY(1,1) NOT NULL,
	[SatisId] [int] NOT NULL,
	[StokId] [int] NOT NULL,
	[Adet] [int] NOT NULL,
	[Fiyat] [decimal](18, 2) NOT NULL,
	[Tutar] [decimal](18, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[DetayId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Satislar]

-- %%
/****** Object:  Table [dbo].[Satislar]    Script Date: 29.01.2026 12:42:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Satislar](
	[SatisId] [int] IDENTITY(1,1) NOT NULL,
	[Tarih] [datetime] NOT NULL,
	[ToplamTutar] [decimal](18, 2) NOT NULL,
	[OdemeYontemi] [nvarchar](50) NOT NULL,
	[ReferansKod] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[SatisId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[stok]

-- %%
/****** Object:  Table [dbo].[stok]    Script Date: 29.01.2026 12:42:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[stok](
	[StokId] [int] IDENTITY(1,1) NOT NULL,
	[StokKodu] [nvarchar](50) NULL,
	[Barkod] [nvarchar](50) NULL,
	[StokAdi] [nvarchar](100) NULL,
	[AlisFiyat] [decimal](10, 2) NULL,
	[SatisFiyat] [decimal](10, 2) NULL,
	[Aciklama] [nvarchar](250) NULL,
	[Birim] [nvarchar](20) NULL,
	[MinimumStok] [int] NULL,
	[Adet] [int] NULL,
	[Resim] [varbinary](max) NULL,
	[Tarih] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[StokId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tedarikciler]

-- %%
/****** Object:  Table [dbo].[Tedarikciler]    Script Date: 29.01.2026 12:42:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tedarikciler](
	[TedarikciId] [int] IDENTITY(1,1) NOT NULL,
	[FirmaAdi] [nvarchar](100) NOT NULL,
	[YetkiliAdSoyad] [nvarchar](100) NULL,
	[Telefon] [nvarchar](20) NULL,
	[Adres] [nvarchar](200) NULL,
	[VergiNo] [nvarchar](50) NULL,
	[Tarih] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[TedarikciId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__stok__Tarih__37A5467C]

-- %%
ALTER TABLE [dbo].[stok] ADD  DEFAULT (getdate()) FOR [Tarih]
GO

-- %% [markdown]
-- # [DF__Tedarikci__Tarih__403A8C7D]

-- %%
ALTER TABLE [dbo].[Tedarikciler] ADD  DEFAULT (getdate()) FOR [Tarih]
GO

-- %% [markdown]
-- # [FK__AlisDetay__AlisI__5070F446]

-- %%
ALTER TABLE [dbo].[AlisDetay]  WITH CHECK ADD FOREIGN KEY([AlisId])
REFERENCES [dbo].[Alislar] ([AlisId])
GO

-- %% [markdown]
-- # [FK__AlisDetay__StokI__5165187F]

-- %%
ALTER TABLE [dbo].[AlisDetay]  WITH CHECK ADD FOREIGN KEY([StokId])
REFERENCES [dbo].[stok] ([StokId])
GO

-- %% [markdown]
-- # [FK__Alislar__Tedarik__4D94879B]

-- %%
ALTER TABLE [dbo].[Alislar]  WITH CHECK ADD FOREIGN KEY([TedarikciId])
REFERENCES [dbo].[Tedarikciler] ([TedarikciId])
GO

-- %% [markdown]
-- # [FK__SatisDeta__Satis__3C69FB99]

-- %%
ALTER TABLE [dbo].[SatisDetay]  WITH CHECK ADD FOREIGN KEY([SatisId])
REFERENCES [dbo].[Satislar] ([SatisId])
GO

-- %% [markdown]
-- # [FK__SatisDeta__StokI__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[SatisDetay]  WITH CHECK ADD FOREIGN KEY([StokId])
REFERENCES [dbo].[stok] ([StokId])
GO
